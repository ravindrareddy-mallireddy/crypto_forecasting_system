# %% [markdown]
# # full_analysis.ipynb
# This notebook should contain:
# - Data cleaning
# - EDA
# - Feature engineering
# - Model training (Prophet, ARIMA, LSTM, Regression)
# - Backtesting & evaluation
# - Export of cleaned data and trained models
